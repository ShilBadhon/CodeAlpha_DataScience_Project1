# %%
import pandas as pd
data = pd.read_csv('/content/Iris.csv')
print(data.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
data = pd.read_csv('/content/Iris.csv')

# %%
sns.scatterplot(data=data, x='SepalLengthCm', y='SepalWidthCm', hue='Species', palette='bright')
plt.title('Sepal Length vs Sepal Width by Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
sns.pairplot(data, hue='Species', diag_kind='kde', palette='bright')
plt.suptitle('Pair Plot of Iris Dataset Features', y=1.02)
plt.show()

# %%
sns.boxplot(data=data, x='Species', y='PetalLengthCm', palette='pastel')
plt.title('Distribution of Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.show()
# Out:
# <ipython-input-5-9560f09656c8>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Species', y='PetalLengthCm', palette='pastel')

# %%
sns.pairplot(data, hue='Species', diag_kind='kde', palette='bright')
plt.suptitle('Pair Plot of Iris Dataset Features', y=1.02)
plt.show()

# %%
sns.boxplot(data=data, x='Species', y='PetalLengthCm', palette='pastel')
plt.title('Distribution of Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.show()
# Out:
# <ipython-input-7-9560f09656c8>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Species', y='PetalLengthCm', palette='pastel')

# %%
correlation_matrix = data.drop(columns=['Id', 'Species']).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Feature Correlation Heatmap')
plt.show()
